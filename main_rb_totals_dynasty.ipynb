# %%
from scrape import get_results
from scrape import get_data
from scrape import grab_years_played
from scrape import revised_run
from scrape import train_test
from scrape import read_adps
from scrape import summarize_tot

# %% [markdown]
# 2022 WR Projections

# %%
X_train2022, X_test2022 = train_test('wr', num_years=5, year_for=2022, totals=True)
X_train2022.head(10)
# Out:
#                name age years_played games_played   avg_rec    avg_tgt  \
# 0       cooper-kupp  28            4           17  8.529412  11.235294
# 1     davante-adams  28            7           16  7.687500  10.562500
# 2      deebo-samuel  25            2           16  4.812500   7.562500
# 3  justin-jefferson  22            1           17  6.352941   9.823529
# 4      jamarr-chase  21            0           17  4.764706   7.529412
# 5       tyreek-hill  27            5           17  6.529412   9.352941
# 6      stefon-diggs  27            6           17  6.058824   9.647059
# 7   diontae-johnson  25            2           16  6.687500  10.562500
# 8        mike-evans  27            7           16  4.625000   7.125000
# 9    hunter-renfrow  25            2           17  6.058824   7.529412
#
#       avg_yds    avg_ypr     avg_lg    avg_TD  ...  TM TGT %   ADP  \
# 0  114.529412  13.776471  37.352941  0.941176  ...      31.5   3.0
# ...

# %%
xgbPPR_results = revised_run(X_train2022, X_test2022, 'wr', year_for='2022', totals=True)
xgbPPR_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 65.82239401696114
# ======= Fold 1 ========
# Our accuracy on the validation set is 82.48213641744934
# ======= Fold 2 ========
# Our accuracy on the validation set is 79.77189597411056
# ======= Fold 3 ========
# Our accuracy on the validation set is 60.10967165071699
# ======= Fold 4 ========
# Our accuracy on the validation set is 70.8254982455262
# Overall accuracy: 71.80231926095284
# iteration 1: Dimensions = (89, 2)
# iteration 2: Dimensions = (178, 2)
# iteration 3: Dimensions = (267, 2)
# iteration 4: Dimensions = (356, 2)
# iteration 5: Dimensions = (445, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0            jamarr-chase  251.849951     1         11
# 1          amonra-stbrown  248.357910     2          7
# 2             ceedee-lamb  247.090479     3          5
# 3        justin-jefferson  244.783398     4          1
# ...

# %%
enetPPR_results = revised_run(X_train2022, X_test2022, 'wr', model_ = 'enet', pca=False, totals=True)
enetPPR_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 63.59387937607362
# ======= Fold 1 ========
# Our accuracy on the validation set is 82.25699264732583
# ======= Fold 2 ========
# Our accuracy on the validation set is 79.19378619584698
# ======= Fold 3 ========
# Our accuracy on the validation set is 60.55816941179507
# ======= Fold 4 ========
# Our accuracy on the validation set is 70.34533109288876
# Overall accuracy: 71.18963174478606
# iteration 1: Dimensions = (89, 2)
# iteration 2: Dimensions = (178, 2)
# iteration 3: Dimensions = (267, 2)
# iteration 4: Dimensions = (356, 2)
# iteration 5: Dimensions = (445, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0        justin-jefferson  254.946933     1          1
# 1            jamarr-chase  245.374861     2         11
# 2           davante-adams  244.489790     3          3
# 3             ceedee-lamb  242.990378     4          5
# ...

# %%
rfPPR_results = revised_run(X_train2022, X_test2022, 'wr', model_ = 'rf', pca=False, totals=True)
rfPPR_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 65.26650190824527
# ======= Fold 1 ========
# Our accuracy on the validation set is 82.07667489525917
# ======= Fold 2 ========
# Our accuracy on the validation set is 76.82591920901659
# ======= Fold 3 ========
# Our accuracy on the validation set is 63.00759021955896
# ======= Fold 4 ========
# Our accuracy on the validation set is 70.11976061919424
# Overall accuracy: 71.45928937025485
# iteration 1: Dimensions = (89, 2)
# iteration 2: Dimensions = (178, 2)
# iteration 3: Dimensions = (267, 2)
# iteration 4: Dimensions = (356, 2)
# iteration 5: Dimensions = (445, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name  proj fpts  rank  last rank
# 0            jamarr-chase   309.7462     1         11
# 1          garrett-wilson   298.1960     2         21
# 2             ceedee-lamb   284.7268     3          5
# 3            deebo-samuel   283.5004     4         38
# ...

# %%
svrPPR_results = revised_run(X_train2022, X_test2022, 'wr', model_ = 'svr', totals=True)
svrPPR_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 58.373525297151104
# ======= Fold 1 ========
# Our accuracy on the validation set is 85.56070419029086
# ======= Fold 2 ========
# Our accuracy on the validation set is 81.82565768279478
# ======= Fold 3 ========
# Our accuracy on the validation set is 66.46221869037467
# ======= Fold 4 ========
# Our accuracy on the validation set is 70.2706703855373
# Overall accuracy: 72.49855524922975
# iteration 1: Dimensions = (89, 2)
# iteration 2: Dimensions = (178, 2)
# iteration 3: Dimensions = (267, 2)
# iteration 4: Dimensions = (356, 2)
# iteration 5: Dimensions = (445, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0        justin-jefferson  270.711308     1          1
# 1           davante-adams  262.037719     2          3
# 2             ceedee-lamb  253.822101     3          5
# 3             tyreek-hill  253.531165     4          2
# ...

# %%
X_train2022, X_test2022 = train_test('wr', num_years=5, year_for=2022, scoring='HALF', totals=True)
xgbHALF_results = revised_run(X_train2022, X_test2022, 'wr', year_for='2022', scoring='HALF', totals=True)
xgbHALF_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 57.89932310062104
# ======= Fold 1 ========
# Our accuracy on the validation set is 69.26053500410907
# ======= Fold 2 ========
# Our accuracy on the validation set is 63.373836451747486
# ======= Fold 3 ========
# Our accuracy on the validation set is 67.16074005103772
# ======= Fold 4 ========
# Our accuracy on the validation set is 47.396689189243034
# Overall accuracy: 61.01822475935167
# iteration 1: Dimensions = (82, 2)
# iteration 2: Dimensions = (164, 2)
# iteration 3: Dimensions = (246, 2)
# iteration 4: Dimensions = (328, 2)
# iteration 5: Dimensions = (410, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0          amonra-stbrown  214.920679     1          8
# 1            jamarr-chase  209.270337     2         12
# 2             ceedee-lamb  206.045752     3          6
# 3                aj-brown  195.536157     4          5
# ...

# %%
enetHALF_results = revised_run(X_train2022, X_test2022, 'wr', model_ = 'enet', pca=False, scoring='HALF', totals=True)
enetHALF_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 56.46477102677677
# ======= Fold 1 ========
# Our accuracy on the validation set is 65.9490397235212
# ======= Fold 2 ========
# Our accuracy on the validation set is 60.05088473673847
# ======= Fold 3 ========
# Our accuracy on the validation set is 66.97220582088207
# ======= Fold 4 ========
# Our accuracy on the validation set is 46.69724703629289
# Overall accuracy: 59.22682966884228
# iteration 1: Dimensions = (82, 2)
# iteration 2: Dimensions = (164, 2)
# iteration 3: Dimensions = (246, 2)
# iteration 4: Dimensions = (328, 2)
# iteration 5: Dimensions = (410, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                    name   proj fpts  rank  last rank
# 0      justin-jefferson  188.931618     1          1
# 1          jamarr-chase  187.423258     2         12
# 2           cooper-kupp  187.120963     3         24
# 3           tyreek-hill  186.770442     4          3
# ...

# %%
rfHALF_results = revised_run(X_train2022, X_test2022, 'wr', model_ = 'rf', pca=False, scoring='HALF', totals=True)
rfHALF_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 54.389732731505966
# ======= Fold 1 ========
# Our accuracy on the validation set is 62.81556058108753
# ======= Fold 2 ========
# Our accuracy on the validation set is 63.40651423470107
# ======= Fold 3 ========
# Our accuracy on the validation set is 67.25622588160302
# ======= Fold 4 ========
# Our accuracy on the validation set is 51.7397977366875
# Overall accuracy: 59.92156623311702
# iteration 1: Dimensions = (82, 2)
# iteration 2: Dimensions = (164, 2)
# iteration 3: Dimensions = (246, 2)
# iteration 4: Dimensions = (328, 2)
# iteration 5: Dimensions = (410, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                        name  proj fpts  rank  last rank
# 0              deebo-samuel   283.9658     1         38
# 1            amonra-stbrown   281.4042     2          8
# 2              chris-godwin   277.2566     3         20
# 3               ceedee-lamb   263.7016     4          6
# ...

# %%
svrHALF_results = revised_run(X_train2022, X_test2022, 'wr', year_for='2022', model_='svr', scoring='HALF', totals=True)
svrHALF_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 57.32645848831228
# ======= Fold 1 ========
# Our accuracy on the validation set is 67.29105201361833
# ======= Fold 2 ========
# Our accuracy on the validation set is 65.34780527885236
# ======= Fold 3 ========
# Our accuracy on the validation set is 69.40387625541806
# ======= Fold 4 ========
# Our accuracy on the validation set is 49.151589123762314
# Overall accuracy: 61.704156231992684
# iteration 1: Dimensions = (82, 2)
# iteration 2: Dimensions = (164, 2)
# iteration 3: Dimensions = (246, 2)
# iteration 4: Dimensions = (328, 2)
# iteration 5: Dimensions = (410, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0             ceedee-lamb  218.028418     1          6
# 1            jamarr-chase  214.193262     2         12
# 2          amonra-stbrown  212.508433     3          8
# 3        justin-jefferson  212.498070     4          1
# ...

# %%
mean_results_PPR = xgbPPR_results.append([rfPPR_results, svrPPR_results, enetPPR_results], ignore_index = True)[['name', 'proj fpts']].groupby('name', as_index=False).mean().sort_values('proj fpts', ascending=False)
mean_results_PPR = mean_results_PPR.reset_index(drop=True)
mean_results_PPR['rank'] = mean_results_PPR.index + 1
mean_results_PPR.to_csv('projections/wr_PPR_2022_mean_totals.csv', index = False)
mean_results_PPR.head(50)
# Out:
#                      name   proj fpts  rank
# 0        justin-jefferson  263.209960     1
# 1            jamarr-chase  262.920183     2
# 2             ceedee-lamb  257.157439     3
# 3           davante-adams  252.475472     4
# 4          amonra-stbrown  248.777369     5
# 5                aj-brown  245.374829     6
# 6            stefon-diggs  242.584814     7
# 7             tyreek-hill  239.281620     8
# 8             cooper-kupp  232.079741     9
# 9          garrett-wilson  227.158910    10
# 10          jaylen-waddle  226.871400    11
# 11          devonta-smith  222.435936    12
# 12            tee-higgins  214.519555    13
# 13         christian-kirk  210.121922    14
# 14             dk-metcalf  209.089679    15
# 15          brandon-aiyuk  208.945107    16
# 16            jerry-jeudy  208.593978    17
# 17            chris-olave  207.476795    18
# 18           chris-godwin  201.295096    19
# 19         terry-mclaurin  197.421513    20
# ...

# %%
summarize_tot('wr', '2022', 'PPR')
# Out:
#                 name   rf proj    xgb proj   enet proj    svr proj  \
# 4   justin-jefferson  282.3982  244.783398  254.946933  270.711308
# 0       jamarr-chase  309.7462  251.849951  245.374861  244.709721
# 2        ceedee-lamb  284.7268  247.090479  242.990378  253.822101
# 9      davante-adams  258.8234  244.550977  244.489790  262.037719
# 5     amonra-stbrown  276.2748  248.357910  230.948444  239.528322
# ..               ...       ...         ...         ...         ...
# 88        noah-brown   45.0410   98.536414  103.336249   96.298431
# 75    nelson-agholor   86.6008   83.740149   95.230702   68.056599
# 84    nick-westbrook   65.5136   87.993396   95.148108   81.133024
# 68      randall-cobb   98.0656   71.135742   88.132903   55.247148
# 81     ben-skowronek   78.7390   73.952057   80.742739   57.830763
#
#      mean proj  rank  last rank
# 4   263.209960     1          1
# 0   262.920183     2         11
# 2   257.157439     3          5
# ...

# %%
mean_results_HALF = xgbHALF_results.append([rfHALF_results, svrHALF_results, enetPPR_results], ignore_index = True)[['name', 'proj fpts']].groupby('name', as_index=False).mean().sort_values('proj fpts', ascending=False)
mean_results_HALF = mean_results_HALF.reset_index(drop=True)
mean_results_HALF['rank'] = mean_results_HALF.index + 1
mean_results_HALF.to_csv('projections/wr_HALF_2022_mean_totals.csv', index = False)
mean_results_HALF.head(50)
# Out:
#                      name   proj fpts  rank
# 0          amonra-stbrown  234.945439     1
# 1             ceedee-lamb  232.691537     2
# 2            jamarr-chase  227.878065     3
# 3        justin-jefferson  223.304410     4
# 4            stefon-diggs  215.519181     5
# 5                aj-brown  211.204650     6
# 6             tyreek-hill  210.575047     7
# 7             cooper-kupp  208.414576     8
# 8           devonta-smith  199.430143     9
# 9            chris-godwin  197.656254    10
# 10          davante-adams  197.496290    11
# 11          jaylen-waddle  195.851650    12
# 12            tee-higgins  192.267713    13
# 13             dk-metcalf  192.116085    14
# 14         garrett-wilson  190.133174    15
# 15           drake-london  185.336667    16
# 16            chris-olave  183.843683    17
# 17        michael-pittman  183.281155    18
# 18         christian-kirk  182.812419    19
# 19          brandon-aiyuk  181.315499    20
# ...

# %%
summarize_tot('wr', '2022', 'HALF')
# Out:
#                 name   rf proj    xgb proj   enet proj    svr proj  \
# 1     amonra-stbrown  281.4042  214.920679  181.630948  212.508433
# 3        ceedee-lamb  263.7016  206.045752  183.723807  218.028418
# 5       jamarr-chase  242.6738  209.270337  187.423258  214.193262
# 7   justin-jefferson  234.1446  191.628040  188.931618  212.498070
# 6       stefon-diggs  240.8136  187.845703  183.996632  203.103818
# ..               ...       ...         ...         ...         ...
# 61    devante-parker   95.3050   43.061014   69.240817   41.516507
# 62      quez-watkins   93.7034   41.111880   50.520299   49.579408
# 80   trent-sherfield   74.6052   57.726758   69.414966   49.501873
# 78    nelson-agholor   81.7472   41.848645   60.712212   39.571376
# 77      randall-cobb   81.9480   12.742831   39.725576    4.425583
#
#      mean proj  rank  last rank
# 1   234.945439     1          8
# 3   232.691537     2          6
# 5   227.878065     3         12
# ...
