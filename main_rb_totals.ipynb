# %%
from scrape import get_results
from scrape import get_data
from scrape import grab_years_played
from scrape import revised_run
from scrape import train_test
from scrape import read_adps
from scrape import summarize_tot

# %% [markdown]
# 2022 RB Projections

# %%
X_train2022, X_test2022 = train_test('rb', num_years=5, year_for=2022, totals=True)
X_train2022.head(10)
# Out:
#                     name age years_played games_played   avg_rec   avg_tgt  \
# 0        jonathan-taylor  22            1           17  2.352941  3.000000
# 1          austin-ekeler  26            4           16  4.375000  5.875000
# 2        najee-harris-rb  23            0           17  4.352941  5.529412
# 3              joe-mixon  24            4           16  2.625000  3.000000
# 4           james-conner  26            4           15  2.466667  2.600000
# 5      leonard-fournette  26            4           14  4.928571  6.000000
# 6        ezekiel-elliott  25            5           17  2.764706  3.823529
# 7           alvin-kamara  25            4           13  3.615385  5.153846
# 8  cordarrelle-patterson  30            8           16  3.250000  4.312500
# 9         antonio-gibson  23            1           16  2.625000  3.250000
#
#      avg_yds   avg_ypr     avg_lg    avg_TD   avg_rush    avg_ryds  avg_rypa  \
# ...

# %%
xgbPPR_results = revised_run(X_train2022, X_test2022, 'rb', year_for='2022', totals=True)
xgbPPR_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 80.67937106494516
# ======= Fold 1 ========
# Our accuracy on the validation set is 87.78515597727495
# ======= Fold 2 ========
# Our accuracy on the validation set is 69.76359249855322
# ======= Fold 3 ========
# Our accuracy on the validation set is 66.6019120006799
# ======= Fold 4 ========
# Our accuracy on the validation set is 77.84806097862682
# Overall accuracy: 76.535618504016
# iteration 1: Dimensions = (74, 2)
# iteration 2: Dimensions = (148, 2)
# iteration 3: Dimensions = (222, 2)
# iteration 4: Dimensions = (296, 2)
# iteration 5: Dimensions = (370, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0     christian-mccaffrey  226.122070     1          2
# 1           austin-ekeler  222.985547     2          1
# 2             josh-jacobs  213.483398     3          3
# 3             breece-hall  210.822437     4         42
# ...

# %%
enetPPR_results = revised_run(X_train2022, X_test2022, 'rb', model_ = 'enet', pca=False, totals=True)
enetPPR_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 79.65763557336007
# ======= Fold 1 ========
# Our accuracy on the validation set is 86.96517205194384
# ======= Fold 2 ========
# Our accuracy on the validation set is 70.09147478505845
# ======= Fold 3 ========
# Our accuracy on the validation set is 64.84024877703507
# ======= Fold 4 ========
# Our accuracy on the validation set is 76.19540371630077
# Overall accuracy: 75.54998698073965
# iteration 1: Dimensions = (74, 2)
# iteration 2: Dimensions = (148, 2)
# iteration 3: Dimensions = (222, 2)
# iteration 4: Dimensions = (296, 2)
# iteration 5: Dimensions = (370, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0           austin-ekeler  221.497055     1          1
# 1             josh-jacobs  221.149011     2          3
# 2     christian-mccaffrey  218.860619     3          2
# 3          saquon-barkley  206.779359     4          5
# ...

# %%
rfPPR_results = revised_run(X_train2022, X_test2022, 'rb', model_ = 'rf', pca=False, totals=True)
rfPPR_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 73.13727789749439
# ======= Fold 1 ========
# Our accuracy on the validation set is 87.64865762356413
# ======= Fold 2 ========
# Our accuracy on the validation set is 74.66531233786299
# ======= Fold 3 ========
# Our accuracy on the validation set is 53.793390548685466
# ======= Fold 4 ========
# Our accuracy on the validation set is 72.7030174672814
# Overall accuracy: 72.38953117497768
# iteration 1: Dimensions = (74, 2)
# iteration 2: Dimensions = (148, 2)
# iteration 3: Dimensions = (222, 2)
# iteration 4: Dimensions = (296, 2)
# iteration 5: Dimensions = (370, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                    name  proj fpts  rank  last rank
# 0         austin-ekeler   305.7040     1          1
# 1   christian-mccaffrey   288.1710     2          2
# 2            nick-chubb   230.0052     3          6
# 3           breece-hall   228.6500     4         42
# ...

# %%
svrPPR_results = revised_run(X_train2022, X_test2022, 'rb', model_ = 'svr', totals=True)
svrPPR_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 84.46288649821709
# ======= Fold 1 ========
# Our accuracy on the validation set is 86.45216729360415
# ======= Fold 2 ========
# Our accuracy on the validation set is 70.52873606334583
# ======= Fold 3 ========
# Our accuracy on the validation set is 62.89096462142568
# ======= Fold 4 ========
# Our accuracy on the validation set is 81.38090550660895
# Overall accuracy: 77.14313199664034
# iteration 1: Dimensions = (74, 2)
# iteration 2: Dimensions = (148, 2)
# iteration 3: Dimensions = (222, 2)
# iteration 4: Dimensions = (296, 2)
# iteration 5: Dimensions = (370, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0           austin-ekeler  222.150900     1          1
# 1             josh-jacobs  219.892561     2          3
# 2     christian-mccaffrey  214.543793     3          2
# 3          saquon-barkley  209.859069     4          5
# ...

# %%
X_train2022, X_test2022 = train_test('rb', num_years=5, year_for=2022, scoring='HALF', totals=True)
xgbHALF_results = revised_run(X_train2022, X_test2022, 'rb', year_for='2022', scoring='HALF', totals=True)
xgbHALF_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 81.67628356910237
# ======= Fold 1 ========
# Our accuracy on the validation set is 62.851462127459676
# ======= Fold 2 ========
# Our accuracy on the validation set is 98.74794785222994
# ======= Fold 3 ========
# Our accuracy on the validation set is 68.44573984922694
# ======= Fold 4 ========
# Our accuracy on the validation set is 64.09802688873361
# Overall accuracy: 75.16389205735051
# iteration 1: Dimensions = (69, 2)
# iteration 2: Dimensions = (138, 2)
# iteration 3: Dimensions = (207, 2)
# iteration 4: Dimensions = (276, 2)
# iteration 5: Dimensions = (345, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0           austin-ekeler  203.161548     1          1
# 1             josh-jacobs  198.339722     2          3
# 2          saquon-barkley  197.701282     3          6
# 3     christian-mccaffrey  197.361621     4          2
# ...

# %%
enetHALF_results = revised_run(X_train2022, X_test2022, 'rb', model_ = 'enet', pca=False, scoring='HALF', totals=True)
enetHALF_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 72.42039132365264
# ======= Fold 1 ========
# Our accuracy on the validation set is 63.345446646455784
# ======= Fold 2 ========
# Our accuracy on the validation set is 98.31588917628838
# ======= Fold 3 ========
# Our accuracy on the validation set is 70.63743441815355
# ======= Fold 4 ========
# Our accuracy on the validation set is 58.85086221949132
# Overall accuracy: 72.71400475680834
# iteration 1: Dimensions = (69, 2)
# iteration 2: Dimensions = (138, 2)
# iteration 3: Dimensions = (207, 2)
# iteration 4: Dimensions = (276, 2)
# iteration 5: Dimensions = (345, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                    name   proj fpts  rank  last rank
# 0   christian-mccaffrey  189.887138     1          2
# 1         austin-ekeler  188.878444     2          1
# 2        saquon-barkley  184.800557     3          6
# 3       jonathan-taylor  183.210663     4         34
# ...

# %%
rfHALF_results = revised_run(X_train2022, X_test2022, 'rb', model_ = 'rf', pca=False, scoring='HALF', totals=True)
rfHALF_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 62.94594322548083
# ======= Fold 1 ========
# Our accuracy on the validation set is 63.18557557405805
# ======= Fold 2 ========
# Our accuracy on the validation set is 89.32264971561666
# ======= Fold 3 ========
# Our accuracy on the validation set is 74.93333467593878
# ======= Fold 4 ========
# Our accuracy on the validation set is 68.67092696035019
# Overall accuracy: 71.8116860302889
# iteration 1: Dimensions = (69, 2)
# iteration 2: Dimensions = (138, 2)
# iteration 3: Dimensions = (207, 2)
# iteration 4: Dimensions = (276, 2)
# iteration 5: Dimensions = (345, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                    name  proj fpts  rank  last rank
# 0         austin-ekeler   265.9332     1          1
# 1   christian-mccaffrey   243.9084     2          2
# 2            nick-chubb   233.8214     3          5
# 3           josh-jacobs   218.2590     4          3
# ...

# %%
svrHALF_results = revised_run(X_train2022, X_test2022, 'rb', year_for='2022', model_='svr', scoring='HALF', totals=True)
svrHALF_results.head(50)
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 79.58725097236079
# ======= Fold 1 ========
# Our accuracy on the validation set is 65.05093861208613
# ======= Fold 2 ========
# Our accuracy on the validation set is 87.95138273504402
# ======= Fold 3 ========
# Our accuracy on the validation set is 72.81650945149777
# ======= Fold 4 ========
# Our accuracy on the validation set is 65.15583146491105
# Overall accuracy: 74.11238264717996
# iteration 1: Dimensions = (69, 2)
# iteration 2: Dimensions = (138, 2)
# iteration 3: Dimensions = (207, 2)
# iteration 4: Dimensions = (276, 2)
# iteration 5: Dimensions = (345, 2)
# Index(['name', 'proj fpts', 'rank'], dtype='object')
#                      name   proj fpts  rank  last rank
# 0             josh-jacobs  205.295502     1          3
# 1           austin-ekeler  202.795595     2          1
# 2          saquon-barkley  201.205088     3          6
# 3           derrick-henry  201.199675     4          4
# ...

# %%
mean_results_PPR = xgbPPR_results.append([rfPPR_results, svrPPR_results, enetPPR_results], ignore_index = True)[['name', 'proj fpts']].groupby('name', as_index=False).mean().sort_values('proj fpts', ascending=False)
mean_results_PPR = mean_results_PPR.reset_index(drop=True)
mean_results_PPR['rank'] = mean_results_PPR.index + 1
mean_results_PPR.to_csv('projections/rb_PPR_2022_mean_totals.csv', index = False)
mean_results_PPR.head(50)
# Out:
#                      name   proj fpts  rank
# 0           austin-ekeler  243.084376     1
# 1     christian-mccaffrey  236.924371     2
# 2             josh-jacobs  215.970493     3
# 3          saquon-barkley  209.580150     4
# 4             breece-hall  204.429918     5
# 5              nick-chubb  201.412899     6
# 6       kenneth-walker-rb  193.568713     7
# 7           derrick-henry  192.276793     8
# 8     rhamondre-stevenson  189.966449     9
# 9            tony-pollard  184.712539    10
# 10              joe-mixon  183.221140    11
# 11           dandre-swift  182.314692    12
# 12         travis-etienne  179.501842    13
# 13        jonathan-taylor  178.129973    14
# 14            aaron-jones  174.235815    15
# 15        najee-harris-rb  172.416422    16
# 16          dameon-pierce  170.073336    17
# 17            dalvin-cook  162.059794    18
# 18          miles-sanders  160.899369    19
# 19           alvin-kamara  159.043633    20
# ...

# %%
summarize_tot('rb', '2022', 'PPR')
# Out:
#                    name   rf proj    xgb proj   enet proj    svr proj  \
# 0         austin-ekeler  305.7040  222.985547  221.497055  222.150900
# 1   christian-mccaffrey  288.1710  226.122070  218.860619  214.543793
# 5           josh-jacobs  209.3570  213.483398  221.149011  219.892561
# 4        saquon-barkley  214.8092  206.872974  206.779359  209.859069
# 3           breece-hall  228.6500  210.822437  201.968691  176.278547
# ..                  ...       ...         ...         ...         ...
# 66         nyheim-hines   33.1650   66.277850   73.700016   35.561471
# 61         boston-scott   40.8786   54.519818   52.626042   57.057961
# 70    raheem-blackshear   31.6584   63.661859   62.645702   38.839799
# 71       hassan-haskins   28.8474   52.070447   59.537866   29.514361
# 72          sony-michel   25.7408   41.695670   46.729188   21.776629
#
#      mean proj  rank  last rank
# 0   243.084376     1          1
# 1   236.924371     2          2
# ...

# %%
mean_results_HALF = xgbHALF_results.append([rfHALF_results, svrHALF_results, enetPPR_results], ignore_index = True)[['name', 'proj fpts']].groupby('name', as_index=False).mean().sort_values('proj fpts', ascending=False)
mean_results_HALF = mean_results_HALF.reset_index(drop=True)
mean_results_HALF['rank'] = mean_results_HALF.index + 1
mean_results_HALF.to_csv('projections/rb_HALF_2022_mean_totals.csv', index = False)
mean_results_HALF.head(50)
# Out:
#                    name   proj fpts  rank
# 0         austin-ekeler  223.346850     1
# 1   christian-mccaffrey  214.323222     2
# 2           josh-jacobs  210.760809     3
# 3        saquon-barkley  204.508032     4
# 4            nick-chubb  196.511822     5
# 5         derrick-henry  190.702056     6
# 6       jonathan-taylor  180.728703     7
# 7           breece-hall  177.441964     8
# 8          tony-pollard  175.728354     9
# 9   rhamondre-stevenson  174.187776    10
# 10    kenneth-walker-rb  173.038206    11
# 11            joe-mixon  167.585274    12
# 12       travis-etienne  163.211648    13
# 13      najee-harris-rb  161.832774    14
# 14        dameon-pierce  159.302853    15
# 15        miles-sanders  156.127871    16
# 16         dandre-swift  155.961583    17
# 17          aaron-jones  155.575752    18
# 18         alvin-kamara  154.314004    19
# 19         james-conner  154.123657    20
# 20          dalvin-cook  153.665920    21
# ...

# %%
summarize_tot('rb', '2022', 'HALF')
# Out:
#                    name   rf proj    xgb proj   enet proj    svr proj  \
# 0         austin-ekeler  265.9332  203.161548  188.878444  202.795595
# 1   christian-mccaffrey  243.9084  197.361621  189.887138  197.162248
# 3           josh-jacobs  218.2590  198.339722  178.594976  205.295502
# 4        saquon-barkley  212.3464  197.701282  184.800557  201.205088
# 2            nick-chubb  233.8214  174.163684  181.227808  195.251300
# ..                  ...       ...         ...         ...         ...
# 35          matt-breida  137.2440   37.077490   51.498710   41.516772
# 16       hassan-haskins  150.1044   38.597974   12.590520   16.954273
# 39         nyheim-hines  134.9978   32.537552   24.675652   22.300326
# 29          sony-michel  142.2942   38.590085   51.967629   32.204520
# 26         travis-homer  142.8100   26.693024    1.389354   18.666644
#
#      mean proj  rank  last rank
# 0   223.346850     1          1
# 1   214.323222     2          2
# ...
